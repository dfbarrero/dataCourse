# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import StandardScaler

header = ["Sonar"+str(i) for i in range(24)]
header.append("Action")

data = pd.read_csv("sensor_readings_24.data", names=header)
data.describe()
# Out:
#             Sonar0       Sonar1       Sonar2       Sonar3       Sonar4  \
# count  5456.000000  5456.000000  5456.000000  5456.000000  5456.000000
# mean      1.471617     2.327043     2.489347     2.796501     2.958552
# std       0.802801     1.410146     1.247435     1.309368     1.339225
# min       0.400000     0.437000     0.470000     0.833000     1.120000
# 25%       0.921000     1.362000     1.538750     1.731000     1.774000
# 50%       1.335000     1.904500     2.064000     2.458000     2.667000
# 75%       1.814000     2.681500     2.739250     4.093500     4.314500
# max       5.000000     5.025000     5.029000     5.017000     5.000000
#
#             Sonar5       Sonar6       Sonar7       Sonar8       Sonar9  \
# count  5456.000000  5456.000000  5456.000000  5456.000000  5456.000000
# mean      2.893073     3.351113     2.540397     3.125621     2.832386
# std       1.282575     1.413692     1.111554     1.356965     1.307843
# min       1.114000     1.122000     0.859000     0.836000     0.810000
# 25%       1.785750     1.930750     1.618000     1.799750     1.636000
# 50%       2.682500     3.225500     2.172000     2.802000     2.679000
# 75%       3.835250     5.000000     3.193000     5.000000     3.526250
# max       5.005000     5.008000     5.087000     5.000000     5.022000
#
#           ...           Sonar14      Sonar15      Sonar16      Sonar17  \
# count     ...       5456.000000  5456.000000  5456.000000  5456.000000
# mean      ...          2.205772     1.202111     0.989831     0.910273
# std       ...          1.715435     1.098568     0.942075     0.889527
# min       ...          0.495000     0.424000     0.373000     0.354000
# 25%       ...          0.860000     0.690000     0.581000     0.529750
# 50%       ...          1.328500     0.803000     0.738000     0.685000
# 75%       ...          4.436250     1.159000     0.913000     0.837000
# max       ...          5.000000     5.000000     5.000000     5.000000
#
#           Sonar18      Sonar19      Sonar20      Sonar21      Sonar22  \
# count  5456.00000  5456.000000  5456.000000  5456.000000  5456.000000
# mean      1.05811     1.076320     1.015923     1.778034     1.555045
# std       1.14463     1.141498     0.887439     1.571686     1.291447
# min       0.34000     0.355000     0.380000     0.370000     0.367000
# 25%       0.52300     0.541750     0.567000     0.743000     0.792000
# 50%       0.69100     0.693000     0.764000     1.030500     1.071000
# 75%       0.85700     0.863000     1.002250     2.068250     1.559500
# max       5.00000     5.000000     5.000000     5.000000     5.000000
#
#            Sonar23
# count  5456.000000
# mean      1.578508
# std       1.150480
# min       0.377000
# 25%       0.884000
# 50%       1.289000
# 75%       1.657250
# max       5.000000
#
# [8 rows x 24 columns]

# %%
data['Action'].describe()
# Out:
# count             5456
# unique               4
# top       Move-Forward
# freq              2205
# Name: Action, dtype: object

# %%
X = data.iloc[:, :-1]
Y = data.iloc[:, -1]

# %%
clf = MLPClassifier(solver='adam', hidden_layer_sizes=(5, 2))
scores = cross_val_score(clf, X, Y, cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Accuracy: 0.71 (+/- 0.09)
# /anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
scaller = StandardScaler()
a = scaller.fit(X)

# %%
a
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
