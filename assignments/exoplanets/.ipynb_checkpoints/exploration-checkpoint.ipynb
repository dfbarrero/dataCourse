# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("planets.csv", skiprows=34)

# %%
data.head()
# Out:
#    loc_rowid pl_hostname pl_letter     pl_name    pl_discmethod  pl_pnum  \
# 0          1      11 Com         b    11 Com b  Radial Velocity        1
# 1          2      11 UMi         b    11 UMi b  Radial Velocity        1
# 2          3      14 And         b    14 And b  Radial Velocity        1
# 3          4      14 Her         b    14 Her b  Radial Velocity        1
# 4          5    16 Cyg B         b  16 Cyg B b  Radial Velocity        1
#
#     pl_orbper  pl_orbsmax  pl_orbeccen  pl_orbincl  \
# 0   326.03000        1.29        0.231         NaN
# 1   516.21997        1.53        0.080         NaN
# 2   185.84000        0.83        0.000         NaN
# 3  1773.40002        2.93        0.370         NaN
# 4   798.50000        1.66        0.680         NaN
#
#                     ...                          dec st_dist  st_optmag  \
# 0                   ...                    17.792868   93.37      4.740
# ...

# %%
data.describe()
# Out:
#          loc_rowid      pl_pnum     pl_orbper   pl_orbsmax  pl_orbeccen  \
# count  3826.000000  3826.000000  3.732000e+03  2173.000000  1203.000000
# mean   1913.500000     1.772608  2.387994e+03     6.953685     0.168452
# std    1104.615393     1.166882  1.198758e+05    83.977130     0.194047
# min       1.000000     1.000000  9.070629e-02     0.004400     0.000000
# 25%     957.250000     1.000000  4.580151e+00     0.058000     0.016850
# 50%    1913.500000     1.000000  1.190533e+01     0.119000     0.101000
# 75%    2869.750000     2.000000  4.180677e+01     0.689000     0.250000
# max    3826.000000     8.000000  7.300000e+06  2500.000000     0.970000
#
#        pl_orbincl    pl_bmassj      pl_radj     pl_dens   pl_ttvflag  \
# count  707.000000  1416.000000  3022.000000  389.000000  3826.000000
# mean    86.119272     2.609544     0.361643    2.489962     0.061945
# std      7.984802     4.521466     0.415049    5.238963     0.241086
# ...

# %%
data.isnull().sum(axis = 0)
# Out:
# loc_rowid           0
# pl_hostname         0
# pl_letter           0
# pl_name             0
# pl_discmethod       0
# pl_pnum             0
# pl_orbper          94
# pl_orbsmax       1653
# pl_orbeccen      2623
# pl_orbincl       3119
# pl_bmassj        2410
# pl_bmassprov     2410
# pl_radj           804
# pl_dens          3437
# pl_ttvflag          0
# pl_kepflag          0
# pl_k2flag           0
# pl_nnotes           0
# ra_str              0
# ra                  0
# dec_str             0
# dec                 0
# st_dist            13
# st_optmag         141
# st_optband        141
# gaia_gmag         133
# st_teff           156
# st_mass           774
# st_rad            258
# rowupdate           0
# pl_facility         0
# dtype: int64

# %%
plt.hist(data['pl_discmethod'])

# %%
sns.dist(data['st_mass'])

# %%
dir(data['st_mass'])
