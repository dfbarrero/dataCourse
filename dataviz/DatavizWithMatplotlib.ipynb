# %% [markdown]
# # Data visualization with Matplotlib
#
# <img src="https://github.com/dfbarrero/dataCourse/raw/master/dataviz/figs/matplotlib.png" width="300">
#
# This notebook takes several contents from the book [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/04.00-introduction-to-matplotlib.html) and [this tutorial](https://www.geeksforgeeks.org/matplotlib-tutorial/).
#
# A may check out this reference with all [plots](https://matplotlib.org/stable/plot_types/index.html) available in Matplotlib and many interesting [examples here](https://matplotlib.org/stable/gallery/index.html).
#
# ## Introduction
#
# Matplotlib is a Python package:
#
# - Based on NumPy
# - Imitates Matlab
#
# Three operation modes:
#
# - Scripts. **Must use plt.show() to enter event loop**. Use it once!
# - IPython shell. Must use %matplotlib
# - IPython notebook. Two modes
#         * %matplotlib inline
#         * %matplotlib notebook

# %% [markdown]
# ## Initial setup

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# Graphical device must by initialized to avoid unexpected behavior.
#
# Two modes:
# - notebook: interactive, only for browser-based devices
# - inline: static
#
# ### Notebook mode
#
# Provides an interactive interface.

# %%
# %matplotlib notebook

x = np.linspace(0, 10, 100) # We begin to do things
plt.plot(x, np.cos(x)); # And here we go!
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Inline mode
#
# Static interface.

# %%
# %matplotlib inline

plt.plot(x, np.cos(x)); # And here we go!

# %% [markdown]
# ## Matplotlib interfaces
#
# Matplotlib comes with two different interfaces.
#
# - Matlab-like. Old-fashioned function-oriented API. Provided by the *matplotlib.plt* module.

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# - Object-oriented. Object-oriented and more powerfull API.

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(x, np.sin(x))
ax.set_title("A sine curve")
ax.set_xlabel("x")
ax.set_ylabel("sin(x)");

# %% [markdown]
# Two concepts to know:
# - Figure: The canvas, it can contain several axes.
# -Axes: The plot (do not confuse with axis!).

# %% [markdown]
# ## Multiple plots
#
# Several methods to draw several plots.

# %%
import matplotlib.pyplot as plt # plt provides Matlab API style

plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

ax[0].set_title("sin(x)")
ax[0].set_ylabel("y")
ax[1].set_title("cos(x)")
ax[1].set_ylabel("y");

# %%
fig = plt.figure(figsize =(5, 4)) 
  
# Creating first axes for the figure
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
  
# Creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])
  
# Adding the data to be plotted
ax1.plot(x, np.sin(x))
ax2.plot([1, 2, 3, 4, 5], [2, 3, 4, 5, 6])
plt.show()

# %% [markdown]
# Adjust lines

# %%
plt.plot(x, x + 0, '-')  # solid default color
plt.plot(x, x + 1, '-g')  # solid green
plt.plot(x, x + 2, '--c') # dashed cyan
plt.plot(x, x + 3, '-.k') # dashdot black
plt.plot(x, x + 4, ':r');  # dotted red

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
  
# Adding the legends
plt.legend(["sin(x)", "cos(x)"])
plt.show()

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.ylim(-2,2)

plt.legend();

# %% [markdown]
# ## Plots
# ### Scatter plots

# %%
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(np.random.random(5), np.random.random(5), marker, label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8)
# Out:
# (0.0, 1.8)

# %%
plt.scatter(x, np.sin(x), marker='x', color="red")

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar()

# %% [markdown]
# ### Histograms

# %%
plt.hist(np.random.randn(1000));

# %%
plt.hist(np.random.randn(1000), bins=30, alpha=0.5);

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

plt.hist(x1, histtype='stepfilled', alpha=0.3, density=True, bins=40)
plt.hist(x2, histtype='stepfilled', alpha=0.3, density=True, bins=40)
plt.hist(x3, histtype='stepfilled', alpha=0.3, density=True, bins=40);

# %%
x = [3, 1, 3, 12, 2, 4, 4] 
y = [3, 2, 1, 4, 5, 6, 7] 
  
plt.bar(x, y)
  
plt.title("Bar Chart")
  
plt.legend(["bar"])

# %% [markdown]
# ## Three-dimensional plots

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
z = [1, 8, 27, 64, 125]
# Creating the figure object
fig = plt.figure()
# keeping the projection = 3d
# ctreates the 3d plot
ax = plt.axes(projection = '3d')
ax.plot3D(z, y, x);

# %%
ax = plt.axes(projection = "3d")

# Data for a three−dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, "gray")

# Data for three−dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c = zdata, cmap = "Greens");

# %%
from matplotlib import cm

n_radii = 8
n_angles = 36

# Make radii and angles spaces
radii = np.linspace(0.125, 1.0, n_radii)
angles = np.linspace(0, 2*np.pi, n_angles, endpoint=False)[..., np.newaxis]

# Convert polar (radii, angles) coords to cartesian (x, y) coords.
x = np.append(0, (radii*np.cos(angles)).flatten())
y = np.append(0, (radii*np.sin(angles)).flatten())
z = np.sin(-x*y)

# Plot
fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_trisurf(x, y, z, vmin=z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[]);

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[]);

# %% [markdown]
# Prepare data.

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %% [markdown]
# 3-D visualizations:

# %%
plt.contour(X, Y, Z, colors='black');

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %% [markdown]
# ## Images

# %%
# importing required libraries 
import matplotlib.pyplot as plt 
import matplotlib.image as img 
import PIL, urllib

# reading the image 
file = urllib.request.urlopen("https://github.com/dfbarrero/dataCourse/raw/master/dataviz/figs/matplotlib.png")
testImage = np.array(PIL.Image.open(file))

# displaying the image 
plt.imshow(testImage);

# %% [markdown]
# ## Final remarks

# %% [markdown]
# Save plot to file

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# Supported file formats

# %%
plt.gcf().canvas.get_supported_filetypes_grouped()
# Out:
# {'Encapsulated Postscript': ['eps'],
#  'Joint Photographic Experts Group': ['jpeg', 'jpg'],
#  'Portable Document Format': ['pdf'],
#  'PGF code for LaTeX': ['pgf'],
#  'Portable Network Graphics': ['png'],
#  'Postscript': ['ps'],
#  'Raw RGBA bitmap': ['raw', 'rgba'],
#  'Scalable Vector Graphics': ['svg', 'svgz'],
#  'Tagged Image File Format': ['tif', 'tiff']}
